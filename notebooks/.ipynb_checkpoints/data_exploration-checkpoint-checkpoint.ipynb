# %%
# !pip install category_encoders
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("../data/fuel_train.csv")
print(f"Any missing values : {data.isnull().values.any()}")
data
# Out:
# Any missing values : False
#      Year           MAKE                      MODEL            VEHICLE CLASS  \
# 0    2000     VOLKSWAGEN                        GTI                  COMPACT
# 1    2000          DODGE                 DAKOTA 4X4  PICKUP TRUCK - STANDARD
# 2    2000            GMC               C1500 SIERRA  PICKUP TRUCK - STANDARD
# 3    2000           FORD                   F150 4X4  PICKUP TRUCK - STANDARD
# 4    2000           FORD                   F150 4X4  PICKUP TRUCK - STANDARD
# ..    ...            ...                        ...                      ...
# 506  2000      CHEVROLET            ASTRO AWD CARGO              VAN - CARGO
# 507  2000      CHEVROLET        K1500 SILVERADO 4X4  PICKUP TRUCK - STANDARD
# 508  2000           FORD                     TAURUS                 MID-SIZE
# 509  2000  MERCEDES-BENZ       SLK 230 KOMPRESSOR #               SUBCOMPACT
# 510  2000      CHEVROLET  G1500/G2500 CHEVY EXPRESS          VAN - PASSENGER
#
# ...

# %%
data.groupby('Year')['FUEL CONSUMPTION'].mean()
# Out:
# Year
# 2000    14.532485
# Name: FUEL CONSUMPTION, dtype: float64

# %%
data.groupby('MAKE')['FUEL CONSUMPTION'].mean()
# Out:
# MAKE
# ACURA            12.557143
# AUDI             14.361111
# BMW              14.795455
# BUICK            13.900000
# CADILLAC         15.233333
# CHEVROLET        15.418750
# CHRYSLER         13.893750
# DAEWOO           11.811111
# DODGE            18.762162
# FERRARI          25.200000
# FORD             15.908511
# GMC              17.651724
# HONDA            11.214286
# HYUNDAI          12.000000
# INFINITI         13.525000
# ISUZU            15.642857
# JAGUAR           15.814286
# JEEP             16.457143
# KIA              12.275000
# LAND ROVER       20.225000
# LEXUS            15.183333
# LINCOLN          16.450000
# MAZDA            13.575000
# MERCEDES-BENZ    14.040000
# NISSAN           15.225000
# OLDSMOBILE       13.380000
# PLYMOUTH         15.400000
# PONTIAC          12.515789
# PORSCHE          15.557143
# SAAB             13.685714
# SATURN           11.014286
# SUBARU           12.166667
# SUZUKI           10.830769
# TOYOTA           12.975676
# ...

# %%
data.groupby('MODEL')['FUEL CONSUMPTION'].mean()
# Out:
# MODEL
# 1.6EL              10.15
# 3.5RL              15.00
# 300M               14.40
# 323 CONVERTIBLE    13.90
# 323Ci              13.40
#                    ...
# XTERRA             14.20
# XTERRA V6          16.20
# XTERRA V6 4X4      16.75
# Z3                 13.90
# Z8                 19.30
# Name: FUEL CONSUMPTION, Length: 292, dtype: float64

# %%
data['MODEL'].value_counts()
# Out:
# MODEL
# LS                      6
# DAKOTA                  5
# A6 QUATTRO              5
# 626                     4
# A4 QUATTRO              4
#                        ..
# CABRIO                  1
# 3.5RL                   1
# HOMBRE 4X4              1
# ACCORD                  1
# SLK 230 KOMPRESSOR #    1
# Name: count, Length: 292, dtype: int64

# %%
data.groupby('VEHICLE CLASS')['FUEL CONSUMPTION'].mean()
# Out:
# VEHICLE CLASS
# COMPACT                     12.305747
# FULL-SIZE                   14.452174
# MID-SIZE                    13.682813
# MINICOMPACT                 14.677778
# MINIVAN                     15.885714
# PICKUP TRUCK - SMALL        14.110000
# PICKUP TRUCK - STANDARD     17.370667
# STATION WAGON - MID-SIZE    13.240000
# STATION WAGON - SMALL       11.963636
# SUBCOMPACT                  12.088158
# SUV                         15.984615
# TWO-SEATER                  16.928571
# VAN - CARGO                 18.011765
# VAN - PASSENGER             19.323077
# Name: FUEL CONSUMPTION, dtype: float64

# %%
data.groupby('TRANSMISSION')['FUEL CONSUMPTION'].mean()
# Out:
# TRANSMISSION
# A3     12.777778
# A4     15.266016
# A5     14.944643
# AS4    14.400000
# AS5    15.800000
# M5     13.024051
# M6     17.018750
# Name: FUEL CONSUMPTION, dtype: float64

# %%
data.groupby('FUEL')['FUEL CONSUMPTION'].mean()
# Out:
# FUEL
# D     7.260000
# E    20.600000
# N    20.800000
# X    14.489516
# Z    14.791603
# Name: FUEL CONSUMPTION, dtype: float64

# %%
data.drop("Year",axis = 1,inplace = True)
data.drop("MODEL",axis = 1,inplace = True)
data
# Out:
#               MAKE            VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 0       VOLKSWAGEN                  COMPACT          2.0          4
# 1            DODGE  PICKUP TRUCK - STANDARD          4.7          8
# 2              GMC  PICKUP TRUCK - STANDARD          4.8          8
# 3             FORD  PICKUP TRUCK - STANDARD          4.6          8
# 4             FORD  PICKUP TRUCK - STANDARD          4.2          6
# ..             ...                      ...          ...        ...
# 506      CHEVROLET              VAN - CARGO          4.3          6
# 507      CHEVROLET  PICKUP TRUCK - STANDARD          4.3          6
# 508           FORD                 MID-SIZE          3.0          6
# 509  MERCEDES-BENZ               SUBCOMPACT          2.3          4
# 510      CHEVROLET          VAN - PASSENGER          5.7          8
#
#     TRANSMISSION FUEL  FUEL CONSUMPTION  COEMISSIONS
# 0             M5    X              11.2           228
# ...

# %%
data = pd.get_dummies(data,columns = ['FUEL','TRANSMISSION'])
data
# Out:
#               MAKE            VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 0       VOLKSWAGEN                  COMPACT          2.0          4
# 1            DODGE  PICKUP TRUCK - STANDARD          4.7          8
# 2              GMC  PICKUP TRUCK - STANDARD          4.8          8
# 3             FORD  PICKUP TRUCK - STANDARD          4.6          8
# 4             FORD  PICKUP TRUCK - STANDARD          4.2          6
# ..             ...                      ...          ...        ...
# 506      CHEVROLET              VAN - CARGO          4.3          6
# 507      CHEVROLET  PICKUP TRUCK - STANDARD          4.3          6
# 508           FORD                 MID-SIZE          3.0          6
# 509  MERCEDES-BENZ               SUBCOMPACT          2.3          4
# 510      CHEVROLET          VAN - PASSENGER          5.7          8
#
#      FUEL CONSUMPTION  COEMISSIONS   FUEL_D  FUEL_E  FUEL_N  FUEL_X  FUEL_Z  \
# ...

# %%
data = data.replace({True: 1, False: 0})
data
# Out:
# /var/folders/vv/fsyffy014jj_lr9z9nwt_3yr0000gn/T/ipykernel_57125/2339750784.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data = data.replace({True: 1, False: 0})
#               MAKE            VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 0       VOLKSWAGEN                  COMPACT          2.0          4
# 1            DODGE  PICKUP TRUCK - STANDARD          4.7          8
# 2              GMC  PICKUP TRUCK - STANDARD          4.8          8
# 3             FORD  PICKUP TRUCK - STANDARD          4.6          8
# 4             FORD  PICKUP TRUCK - STANDARD          4.2          6
# ..             ...                      ...          ...        ...
# 506      CHEVROLET              VAN - CARGO          4.3          6
# ...

# %%
from category_encoders import TargetEncoder
cols = ['MAKE','VEHICLE CLASS']
for col in cols:
    te = TargetEncoder()
    te.fit(X=data[col],y = data['FUEL CONSUMPTION'])
    values = te.transform(data[col])
    data = pd.concat([data,values],axis = 1)
data
# Out:
#               MAKE            VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 0       VOLKSWAGEN                  COMPACT          2.0          4
# 1            DODGE  PICKUP TRUCK - STANDARD          4.7          8
# 2              GMC  PICKUP TRUCK - STANDARD          4.8          8
# 3             FORD  PICKUP TRUCK - STANDARD          4.6          8
# 4             FORD  PICKUP TRUCK - STANDARD          4.2          6
# ..             ...                      ...          ...        ...
# 506      CHEVROLET              VAN - CARGO          4.3          6
# 507      CHEVROLET  PICKUP TRUCK - STANDARD          4.3          6
# 508           FORD                 MID-SIZE          3.0          6
# 509  MERCEDES-BENZ               SUBCOMPACT          2.3          4
# 510      CHEVROLET          VAN - PASSENGER          5.7          8
#
#      FUEL CONSUMPTION  COEMISSIONS   FUEL_D  FUEL_E  FUEL_N  FUEL_X  FUEL_Z  \
# ...

# %%
data.drop(data.columns[0],axis = 1,inplace=True)
data.drop(data.columns[0],axis = 1,inplace=True)
data
# Out:
#      ENGINE SIZE  CYLINDERS  FUEL CONSUMPTION  COEMISSIONS   FUEL_D  FUEL_E  \
# 0            2.0          4              11.2           228       0       0
# 1            4.7          8              18.8           382       0       0
# 2            4.8          8              18.9           373       0       0
# 3            4.6          8              18.5           380       0       0
# 4            4.2          6              17.3           359       0       0
# ..           ...        ...               ...           ...     ...     ...
# 506          4.3          6              17.0           350       0       0
# 507          4.3          6              18.7           386       0       0
# 508          3.0          6              13.6           267       0       0
# 509          2.3          4              12.6           246       0       0
# 510          5.7          8              20.6           426       0       0
#
# ...

# %%
data['ENGINE SIZE'] = (data['ENGINE SIZE'] - data['ENGINE SIZE'].mean()) / data['ENGINE SIZE'].std()
data['CYLINDERS'] = (data['CYLINDERS'] - data['CYLINDERS'].mean()) / data['CYLINDERS'].std()
data[data.columns[3]] = (datadata.columns[3] - data.columns[3].mean()) / data.columns[3].std()
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'COEMISSIONS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 3
# ...
